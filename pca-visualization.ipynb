# %%
import pandas as pd

coord_df = pd.read_excel("outputs/elements_pca_coordinates-1.xlsx") # change it to the path of your coordinates
coord_df.head(5)
# Out:
#         PC1       PC2 Symbol                  group
# 0 -1.879979 -6.985570     Li          alkali_metals
# 1 -4.602822 -2.530915     Be  alkaline_earth_metals
# 2 -5.422321 -0.072490      B             metalloids
# 3 -6.993542  2.731040      C             non_metals
# 4 -9.639504  1.305678      N             non_metals

# %%
data = pd.read_excel("data/pauling.xlsx") # change it to the path of your data
data.head(5)
# Out:
#   Formula Structure type  molar mass      a  Volume  Sg #     Sg
# 0    AgMg           CsCl       132.2  3.280   35.29   221  Pm-3m
# 1    AlNi           CsCl        85.7  2.820   22.43   221  Pm-3m
# 2    AuZn           CsCl       262.3  3.190   32.46   221  Pm-3m
# 3    BiTl           CsCl       413.4  3.980   63.00   221  Pm-3m
# 4    BrCs           CsCl       212.8  4.287   78.80   221  Pm-3m

# %%
from utils.preprocess import calculate_average_coordinate

marker_df = calculate_average_coordinate(data, coord_df)

marker_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/binary/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 3
#       1 from utils.preprocess import calculate_average_coordinate
# ...

# %%
from utils.pca_visualization import PCA_plot

PCA_plot(coord_df, data, marker_df)
# Out:
# Plot saved as plots/CsCl_PCA_plot_8.png
# <Axes: >
